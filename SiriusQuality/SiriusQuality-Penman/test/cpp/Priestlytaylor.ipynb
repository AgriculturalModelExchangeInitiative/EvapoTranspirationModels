# %% [markdown]
# # Automatic generation of Notebook using PyCropML
#     This notebook implements a crop model.

# %% [markdown]
# ### Model Priestlytaylor

# %%
#include "..\..\src\cpp\SiriusQuality-Penman\PotentialET_PenmanState.cpp"
#include "..\..\src\cpp\SiriusQuality-Penman\PotentialET_PenmanRate.cpp"
#include "..\..\src\cpp\SiriusQuality-Penman\PotentialET_PenmanAuxiliary.cpp"
#include "..\..\src\cpp\SiriusQuality-Penman\PotentialET_PenmanExogenous.cpp"
#include "..\..\src\cpp\SiriusQuality-Penman\PriestlyTaylor.cpp"

# %%
class Test
{
    private:
        Potentialet_penmanState s;
        Potentialet_penmanState s1;
        Potentialet_penmanRate r;
        Potentialet_penmanAuxiliary a;
        Potentialet_penmanExogenous ex;
        Priestlytaylor mod;
    public:
}

# %%
Test t;
