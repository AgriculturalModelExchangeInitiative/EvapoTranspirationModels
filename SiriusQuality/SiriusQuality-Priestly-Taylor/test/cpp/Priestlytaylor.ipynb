# %% [markdown]
# # Automatic generation of Notebook using PyCropML
#     This notebook implements a crop model.

# %% [markdown]
# ### Model Priestlytaylor

# %%
#include "..\..\src\cpp\SiriusQuality-Priestly-Taylor\PotentialET_PTState.cpp"
#include "..\..\src\cpp\SiriusQuality-Priestly-Taylor\PotentialET_PTRate.cpp"
#include "..\..\src\cpp\SiriusQuality-Priestly-Taylor\PotentialET_PTAuxiliary.cpp"
#include "..\..\src\cpp\SiriusQuality-Priestly-Taylor\PotentialET_PTExogenous.cpp"
#include "..\..\src\cpp\SiriusQuality-Priestly-Taylor\PriestlyTaylor.cpp"

# %%
class Test
{
    private:
        Potentialet_ptState s;
        Potentialet_ptState s1;
        Potentialet_ptRate r;
        Potentialet_ptAuxiliary a;
        Potentialet_ptExogenous ex;
        Priestlytaylor mod;
    public:
}

# %%
Test t;
