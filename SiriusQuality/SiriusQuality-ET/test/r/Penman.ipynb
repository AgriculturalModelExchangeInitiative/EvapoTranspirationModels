# %% [markdown]
# # Automatic generation of Notebook using PyCropML
#     This notebook implements a crop model.

# %% [markdown]
# ### Model Penman

# %%
source("../../src/r/SiriusQuality-EnergyBalance/penman.r")
library(assertthat)
