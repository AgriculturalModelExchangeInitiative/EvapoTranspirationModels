# %% [markdown]
# # Automatic generation of Notebook using PyCropML
#     This notebook implements a crop model.

# %% [markdown]
# ### Model Diffusionlimitedevaporation

# %%
source("../../src/r/SiriusQuality-EnergyBalance/diffusionlimitedevaporation.r")
library(assertthat)
