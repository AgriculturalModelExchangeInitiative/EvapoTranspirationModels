# %% [markdown]
# # Automatic generation of Notebook using PyCropML
#     This notebook implements a crop model.

# %% [markdown]
# ### Model Conductance

# %%
source("../../src/r/SiriusQuality-EnergyBalance/conductance.r")
library(assertthat)
