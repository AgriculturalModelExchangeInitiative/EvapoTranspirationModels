# %% [markdown]
# # Automatic generation of Notebook using PyCropML
#     This notebook implements a crop model.

# %% [markdown]
# ### Model Evapotranspiration

# %%
source("../../src/r/SiriusQuality-EnergyBalance/evapotranspiration.r")
library(assertthat)
