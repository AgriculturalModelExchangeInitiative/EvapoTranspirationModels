# %% [markdown]
# # Automatic generation of Notebook using PyCropML
#     This notebook implements a crop model.

# %% [markdown]
# ### Model Soilheatflux

# %%
source("../../src/r/SiriusQuality-EnergyBalance/soilheatflux.r")
library(assertthat)
