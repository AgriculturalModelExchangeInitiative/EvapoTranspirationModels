# %% [markdown]
# # Automatic generation of Notebook using PyCropML
#     This notebook implements a crop model.

# %% [markdown]
# ### Model Netradiation

# %%
source("../../src/r/SiriusQuality-EnergyBalance/netradiation.r")
library(assertthat)
