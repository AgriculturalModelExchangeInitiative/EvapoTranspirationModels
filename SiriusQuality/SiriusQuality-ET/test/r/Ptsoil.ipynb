# %% [markdown]
# # Automatic generation of Notebook using PyCropML
#     This notebook implements a crop model.

# %% [markdown]
# ### Model Ptsoil

# %%
source("../../src/r/SiriusQuality-EnergyBalance/ptsoil.r")
library(assertthat)
