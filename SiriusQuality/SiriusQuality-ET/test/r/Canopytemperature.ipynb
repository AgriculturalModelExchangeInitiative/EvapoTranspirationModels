# %% [markdown]
# # Automatic generation of Notebook using PyCropML
#     This notebook implements a crop model.

# %% [markdown]
# ### Model Canopytemperature

# %%
source("../../src/r/SiriusQuality-EnergyBalance/canopytemperature.r")
library(assertthat)
