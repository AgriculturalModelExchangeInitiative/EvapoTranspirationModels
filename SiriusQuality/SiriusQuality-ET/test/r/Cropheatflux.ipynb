# %% [markdown]
# # Automatic generation of Notebook using PyCropML
#     This notebook implements a crop model.

# %% [markdown]
# ### Model Cropheatflux

# %%
source("../../src/r/SiriusQuality-EnergyBalance/cropheatflux.r")
library(assertthat)
