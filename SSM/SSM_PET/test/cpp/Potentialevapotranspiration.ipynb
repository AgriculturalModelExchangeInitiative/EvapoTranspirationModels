# %% [markdown]
# # Automatic generation of Notebook using PyCropML
#     This notebook implements a crop model.

# %% [markdown]
# ### Model Potentialevapotranspiration

# %%
#include "..\..\src\cpp\SSM_PET\petState.cpp"
#include "..\..\src\cpp\SSM_PET\petRate.cpp"
#include "..\..\src\cpp\SSM_PET\petAuxiliary.cpp"
#include "..\..\src\cpp\SSM_PET\petExogenous.cpp"
#include "..\..\src\cpp\SSM_PET\PotentialEvapotranspiration.cpp"

# %%
class Test
{
    private:
        PetState s;
        PetState s1;
        PetRate r;
        PetAuxiliary a;
        PetExogenous ex;
        Potentialevapotranspiration mod;
    public:
}

# %%
Test t;
