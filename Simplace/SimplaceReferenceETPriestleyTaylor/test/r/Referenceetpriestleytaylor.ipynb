# %% [markdown]
# # Automatic generation of Notebook using PyCropML
#     This notebook implements a crop model.

# %% [markdown]
# ### Model Referenceetpriestleytaylor

# %%
source("../../src/r/SimplaceReferenceETPriestleyTaylor/referenceetpriestleytaylor.r")
library(assertthat)
