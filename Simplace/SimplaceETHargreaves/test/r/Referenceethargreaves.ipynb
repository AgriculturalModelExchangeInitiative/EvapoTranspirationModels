# %% [markdown]
# # Automatic generation of Notebook using PyCropML
#     This notebook implements a crop model.

# %% [markdown]
# ### Model Referenceethargreaves

# %%
source("../../src/r/SimplaceETHargreaves/referenceethargreaves.r")
library(assertthat)
