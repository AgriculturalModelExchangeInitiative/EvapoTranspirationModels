# %% [markdown]
# # Automatic generation of Notebook using PyCropML
#     This notebook implements a crop model.

# %% [markdown]
# ### Model Referenceetpm

# %%
source("../../src/r/SimplaceReferenceETPM/referenceetpm.r")
library(assertthat)
