# %% [markdown]
# # Automatic generation of Notebook using PyCropML
#     This notebook implements a crop model.

# %% [markdown]
# ### Model Referenceetpm

# %%
import numpy
from datetime import datetime
from array import array
import sys
sys.path.append("../../src/py/SimplaceReferenceETPM")
from referenceetpm import model_referenceetpm
